# %% [markdown]
# # Import Necessary Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
BCS = pd.read_csv('baseball.csv')
BCS.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
#checking the dimension of data
BCS.shape
# Out:
# (30, 17)

# %%
BCS.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
BCS.columns.tolist()
# Out:
# ['W',
#  'R',
#  'AB',
#  'H',
#  '2B',
#  '3B',
#  'HR',
#  'BB',
#  'SO',
#  'SB',
#  'RA',
#  'ER',
#  'ERA',
#  'CG',
#  'SHO',
#  'SV',
#  'E']

# %%
BCS.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %%
BCS.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
BCS.isnull().sum().sum()
# Out:
# 0

# %%
BCS.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
#lets visualize it using heatmap
sns.heatmap(BCS.isnull())
# Out:
# <AxesSubplot:>

# %%
#checking the value counts of each column
for i in BCS.columns:
    print(BCS[i].value_counts())
    print("\n")
# Out:
# 68     3
# 83     2
# 74     2
# 76     2
# 81     2
# 64     1
# 93     1
# 92     1
# 90     1
# 88     1
# 87     1
# 86     1
# 85     1
# 84     1
# 80     1
# 97     1
# 100    1
# 78     1
# 63     1
# 79     1
# 71     1
# 67     1
# 98     1
# 95     1
# Name: W, dtype: int64
#
#
# 696    2
# 689    2
# 640    1
# 644    1
# 720    1
# 573    1
# 764    1
# 891    1
# 697    1
# 694    1
# 626    1
# 751    1
# 622    1
# 748    1
# 683    1
# 613    1
# 737    1
# 669    1
# 667    1
# 729    1
# 661    1
# 724    1
# 656    1
# 655    1
# 650    1
# 713    1
# 647    1
# 703    1
# Name: R, dtype: int64
#
#
# 5485    2
# 5571    1
# 5605    1
# 5491    1
# 5565    1
# 5457    1
# 5428    1
# 5420    1
# 5567    1
# 5480    1
# 5439    1
# 5484    1
# 5417    1
# 5544    1
# 5527    1
# 5572    1
# 5600    1
# 5533    1
# 5467    1
# 5529    1
# 5463    1
# 5459    1
# 5649    1
# 5511    1
# 5385    1
# 5640    1
# 5575    1
# 5509    1
# 5631    1
# ...

# %%
BCS.shape[0]
# Out:
# 30

# %%
#Separating Numerical and Categorical columns

#Checking for categorical columns
categorical_col = []
for i in BCS.dtypes.index:
    if BCS.dtypes[i] == "object":
        categorical_col.append(i)
        
print("Categorical Columns: ", categorical_col)
print("\n")

#Checking for Numerical columns
numerical_col = []
for i in BCS.dtypes.index:
    if BCS.dtypes[i]!= "object":
        numerical_col.append(i)
        
print("Numerical Columns: ", numerical_col)
print("\n")
# Out:
# Categorical Columns:  []
#
#
# Numerical Columns:  ['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER', 'ERA', 'CG', 'SHO', 'SV', 'E']

# %%
# Checking number of unique values in each column
BCS.nunique().to_frame("No. of unique values")
# Out:
#      No. of unique values
# W                      24
# R                      28
# AB                     29
# H                      29
# 2B                     22
# 3B                     23
# HR                     27
# BB                     29
# SO                     29
# SB                     27
# RA                     30
# ER                     30
# ERA                    30
# CG                      9
# SHO                    12
# SV                     20
# E                      21

# %% [markdown]
# # Desciption of Dataset

# %%
# Statistical summary of numerical column
BCS.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# # Data Visualization

# %%
#let's check how the data has been distributed in columns
from socket import socket
plt.figure(figsize = (100, 84), facecolor = "white")
plotnumber = 1
for col in numerical_col:
    if plotnumber<=17:
        ax = plt.subplot(6, 3, plotnumber)
        sns.distplot(BCS[col], color = "m")
        plt.xlabel(col, fontsize = 80)
        plt.ylabel('Density', fontsize = 50)
        plt.yticks(rotation = 0, fontsize = 65)
        plt.xticks(rotation = 0, fontsize = 65)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # Checking for Outliers

# %%
# Lets check the outliers by plotting boxplot

plt.figure(figsize = (100, 60), facecolor = "white")
plotnumber = 1
for col in numerical_col:
    if plotnumber<=17:
        ax = plt.subplot(6, 3, plotnumber)
        sns.boxplot(BCS[col], palette = "Set2_r")
        plt.xlabel(col, fontsize = 50)
        plt.xticks(rotation = 0, fontsize = 50)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# # Checking for skweness

# %%
BCS.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# # Findings 1

# %% [markdown]
# Run and win exhibit a linear correlation. Outliers are present between 850 and 900.
#
# Balls are very weakly related to wins, with no outliers.
#
# Hits are also very weakly related to winning, with no outliers.
#
# Doubles have a linear relationship with wins, without outliers, and the data is skewed to the left.
#
# Triples have a very weak negative correlation with wins, with no outliers, and the data is skewed to the right.
#
# Home runs have a very low correlation with wins, with few outliers, and the data is right-skewed.
#
# Walks are lightly correlated with wins, with no outliers.
#
# Strikeouts are not correlated with wins, with no outliers, and the dataset is left-skewed.
#
# Stolen bases are not correlated with wins, with no outliers.
#
# Runs allowed are highly correlated with wins, with no outliers.
#
# Earned runs are highly correlated with wins, with no outliers.
#
# Earned run average (ERA) is not correlated with wins, with no outliers, and the data is right-skewed.
#
# Shutouts are highly correlated with wins, with no outliers, and the data is right-skewed.
#
# Saves are lightly correlated with wins, with no outliers, and the data is skewed.
#
# Errors are not correlated with wins, the data has outliers, and the data is right-skewed.

# %% [markdown]
# # Explanation 1

# %% [markdown]
# The number of runs, home runs, doubles, saves, shutouts, and walks exhibit highly positive linear correlations.
#
# Stolen bases, runs allowed, and earned runs are highly negatively linearly correlated.
#
# The remaining features have little to no linear correlation with the number of wins.
#
# The dataset shows excessive randomness. Moreover, it only contains small sets of data, making it insufficient to form a suitable decision tree.

# %% [markdown]
# # Correlation between target variable and independent variables.

# %%
# Checking the correlation between features and the target
cor = BCS.corr()
cor
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
# Visualizing the correlation matrix by plotting heatmap
plt.figure(figsize = (20, 15))
sns.heatmap(BCS.corr(), linewidths = 0.1, fmt = ".1g", linecolor = "black", annot = True, cmap = 'PiYG')
plt.yticks(rotation = 0);
plt.show()

# %%
cor['W'].sort_values(ascending = False)
# Out:
# W      1.000000
# SV     0.666530
# BB     0.484342
# SHO    0.471805
# R      0.430751
# 2B     0.427797
# HR     0.307407
# SO     0.111850
# CG     0.080533
# H      0.037612
# AB    -0.087947
# E     -0.089485
# SB    -0.157234
# 3B    -0.251118
# ER    -0.809435
# RA    -0.812952
# ERA   -0.819600
# Name: W, dtype: float64

# %% [markdown]
# # Visualizing the correlation between label and features using bar plot

# %%
plt.figure(figsize = (22, 7))
BCS.corr()['W'].sort_values(ascending = False).drop(['W']).plot(kind = 'bar', color = "m")
plt.xlabel('Feature', fontsize = 15)
plt.ylabel('Target', fontsize = 15)
plt.title("Correlation between label and features using barplot", fontsize = 20)
plt.show()

# %% [markdown]
# # Separating features and label

# %%
x = BCS.drop("W", axis = 1)
y = BCS["W"]

# %% [markdown]
# # Feature Scaling using Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns = x.columns)
x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.619078  0.847731  1.663685  1.420173  1.041193 -0.787299 -1.534902
# 1   0.134432 -0.711094 -0.970681  0.127403  1.235809 -0.243967 -0.536592
# 2  -0.332906 -1.115233 -0.151891  1.588795 -0.223808 -0.723377  1.139144
# 3  -1.146419  0.241522 -0.401088 -0.828122 -0.418423 -0.883181 -1.160536
# 4   0.013270  1.280738  1.984081  0.801892  1.722347 -0.403770 -0.251360
# 5   3.509647 -0.104884  1.361089  1.869832 -1.391501  2.185047  1.798742
# 6   1.311430  0.732263 -0.116292 -0.153633 -1.196885  1.545833  1.513510
# 7   0.428681 -0.451289 -0.596886 -1.615025 -1.099578  1.705636 -0.910958
# 8  -0.765626 -0.451289 -0.365489  0.183611  0.068115  0.107601 -0.590073
# 9   1.034489  1.785913  1.628086  1.082929  0.165423 -0.084163  0.158660
# 10  1.086415 -0.076017  0.275303  0.239818  0.068115  0.267405  0.604334
# 11  0.705622 -0.826562 -0.721484  0.183611 -0.515731  2.121125  0.301276
# ...

# %% [markdown]
# # Checking Variance Inflation Factor(VIF)

# %%
# Finding variance inflation factor in each scaled column i.e, x.shape[1] (1/(1-R2))
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values, i)
                     for i in range(len(x.columns))]
vif["Features"] = x.columns

vif
# Out:
#      VIF values Features
# 0     11.522370        R
# 1     13.311532       AB
# 2     10.070668        H
# 3      4.019297       2B
# 4      3.294146       3B
# 5     10.079902       HR
# 6      3.806098       BB
# 7      2.652401       SO
# 8      2.102684       SB
# 9    191.839155       RA
# 10  1680.387145       ER
# 11  1222.722240      ERA
# 12     3.059904       CG
# 13     3.654331      SHO
# 14     5.798850       SV
# 15     2.186219        E

# %%
# Dropping ER column
x.drop("ER", axis = 1, inplace = True)

# %%
# Again checking VIF value to confirm whether the multicollinearity still exists or not
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values, i)
                     for i in range(len(x.columns))]
vif["Features"] = x.columns

vif
# Out:
#     VIF values Features
# 0    11.158733        R
# 1     5.863764       AB
# 2     9.628749        H
# 3     3.786446       2B
# 4     3.293109       3B
# 5     9.057309       HR
# 6     3.791451       BB
# 7     2.607389       SO
# 8     1.849280       SB
# 9   122.133235       RA
# 10  119.328698      ERA
# 11    2.741188       CG
# 12    3.410561      SHO
# 13    3.203815       SV
# 14    2.107345        E

# %%
# Dropping RA column
x.drop("RA", axis = 1, inplace = True)

# %%
# Again checking VIF value to confirm whether the multicollinearity still exists or not
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values, i)
                     for i in range(len(x.columns))]
vif["Features"] = x.columns

vif
# Out:
#     VIF values Features
# 0    10.987898        R
# 1     4.399954       AB
# 2     8.941874        H
# 3     3.729413       2B
# 4     3.142717       3B
# 5     7.882841       HR
# 6     3.468244       BB
# 7     2.155496       SO
# 8     1.819823       SB
# 9     4.951981      ERA
# 10    2.723370       CG
# 11    3.227759      SHO
# 12    2.948133       SV
# 13    2.040676        E

# %%
# Dropping R column
x.drop("R", axis = 1, inplace = True)

# %%
# Again checking VIF value to confirm whether the multicollinearity still exists or not
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values, i)
                     for i in range(len(x.columns))]
vif["Features"] = x.columns

vif
# Out:
#     VIF values Features
# 0     3.581051       AB
# 1     5.045576        H
# 2     3.142250       2B
# 3     2.850183       3B
# 4     1.901062       HR
# 5     2.767793       BB
# 6     1.963486       SO
# 7     1.694043       SB
# 8     4.511081      ERA
# 9     2.260786       CG
# 10    2.972910      SHO
# 11    2.371307       SV
# 12    1.558257        E

# %%
y.value_counts()
# Out:
# 68     3
# 83     2
# 74     2
# 76     2
# 81     2
# 64     1
# 93     1
# 92     1
# 90     1
# 88     1
# 87     1
# 86     1
# 85     1
# 84     1
# 80     1
# 97     1
# 100    1
# 78     1
# 63     1
# 79     1
# 71     1
# 67     1
# 98     1
# 95     1
# Name: W, dtype: int64

# %% [markdown]
# # Modelling

# %% [markdown]
# # Finding the best random state

# %%
# importing necessary libraries:

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.linear_model import LinearRegression

# %%
maxAccu = 0
maxRs = 0
for i in range(1, 200):
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state = i)
    LR = LinearRegression()
    LR.fit(x_train, y_train)
    pred = LR.predict(x_test)
    acc = r2_score(y_test, pred)
    if acc>maxAccu:
        maxAccu = acc
        maxRs = i
        
print("Best accuracy is ", maxAccu, "at random state", maxRs)
# Out:
# Best accuracy is  0.9157317861357003 at random state 157

# %% [markdown]
# # Creating train test split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = maxRs)

# %% [markdown]
# # Regression Algorithm

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.linear_model import Lasso, Ridge
from sklearn.svm import SVR

# %%
LR = LinearRegression()
LR.fit(x_train, y_train)
pred_LR = LR.predict(x_test)
pred_train = LR.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_LR))
print('R2_score on training data:- ',r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:- ',mean_absolute_error(y_test, pred_LR))
print('Mean Squared Error:- ',mean_squared_error(y_test, pred_LR))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test, pred_LR)))
# Out:
# R2_score:  0.9157317861357003
# R2_score on training data:-  85.18692601437017
# Mean Absolute Error:-  2.297360506997396
# Mean Squared Error:-  8.522533431806705
# Root Mean Squared Error:-  2.9193378413274997

# %%
plt.figure(figsize=(10,6))
plt.scatter(x = pred_LR, y = y_test, color = 'r')
plt.plot(pred_LR, pred_LR, color = 'b')
plt.xlabel('Actual', fontsize = 14)
plt.ylabel('Predicted', fontsize = 14)
plt.title("Linear Regression", fontsize = 18)
plt.show()

# %%
RFR = RandomForestRegressor()
RFR.fit(x_train, y_train)
pred_RFR = RFR.predict(x_test)
pred_train = RFR.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_RFR))
print('R2_score on training data:- ',r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:- ',mean_absolute_error(y_test, pred_RFR))
print('Mean Squared Error:- ',mean_squared_error(y_test, pred_RFR))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test, pred_RFR)))
# Out:
# R2_score:  0.6663251098632812
# R2_score on training data:-  91.0967551841806
# Mean Absolute Error:-  4.432222222222222
# Mean Squared Error:-  33.746477777777784
# Root Mean Squared Error:-  5.809171866779101

# %%
KNN = KNN()
KNN.fit(x_train, y_train)
pred_KNN = KNN.predict(x_test)
pred_train = KNN.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_KNN))
print('R2_score on training data:- ',r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:- ',mean_absolute_error(y_test, pred_KNN))
print('Mean Squared Error:- ',mean_squared_error(y_test, pred_KNN))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test, pred_KNN)))
# Out:
# R2_score:  0.6165771484374999
# R2_score on training data:-  44.425059060285264
# Mean Absolute Error:-  4.733333333333334
# Mean Squared Error:-  38.77777777777779
# Root Mean Squared Error:-  6.227180564089803

# %%
GBR = GradientBoostingRegressor()
GBR.fit(x_train, y_train)
pred_GBR = GBR.predict(x_test)
pred_train = GBR.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_GBR))
print('R2_score on training data:- ',r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:- ',mean_absolute_error(y_test, pred_GBR))
print('Mean Squared Error:- ',mean_squared_error(y_test, pred_GBR))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test, pred_GBR)))
# Out:
# R2_score:  0.25312355859719093
# R2_score on training data:-  99.99999445568439
# Mean Absolute Error:-  6.8929275896647635
# Mean Squared Error:-  75.53594824656558
# Root Mean Squared Error:-  8.691141941457726

# %%
LA = Lasso()
LA.fit(x_train, y_train)
pred_LA = LA.predict(x_test)
pred_train = LA.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_LA))
print('R2_score on training data:- ',r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:- ',mean_absolute_error(y_test, pred_LA))
print('Mean Squared Error:- ',mean_squared_error(y_test, pred_LA))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test, pred_LA)))
# Out:
# R2_score:  0.9009517004837124
# R2_score on training data:-  75.53418707384216
# Mean Absolute Error:-  2.825067055927186
# Mean Squared Error:-  10.01732925478306
# Root Mean Squared Error:-  3.1650164699070777

# %%
RD = Ridge()
RD.fit(x_train, y_train)
pred_RD = LR.predict(x_test)
pred_train = RD.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_RD))
print('R2_score on training data:- ',r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:- ',mean_absolute_error(y_test, pred_RD))
print('Mean Squared Error:- ',mean_squared_error(y_test, pred_RD))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test, pred_RD)))
# Out:
# R2_score:  0.9157317861357003
# R2_score on training data:-  84.6814279220082
# Mean Absolute Error:-  2.297360506997396
# Mean Squared Error:-  8.522533431806705
# Root Mean Squared Error:-  2.9193378413274997

# %%
DTR = DecisionTreeRegressor()
DTR.fit(x_train, y_train)
pred_DTR = DTR.predict(x_test)
pred_train = DTR.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_DTR))
print('R2_score on training data:- ',r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:- ',mean_absolute_error(y_test, pred_DTR))
print('Mean Squared Error:- ',mean_squared_error(y_test, pred_DTR))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test, pred_DTR)))
# Out:
# R2_score:  -0.6918945312499998
# R2_score on training data:-  100.0
# Mean Absolute Error:-  10.88888888888889
# Mean Squared Error:-  171.11111111111111
# Root Mean Squared Error:-  13.080944580232389

# %%
svr = SVR()
svr.fit(x_train, y_train)
pred_svr = svr.predict(x_test)
pred_train = svr.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_svr))
print('R2_score on training data:- ',r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:- ',mean_absolute_error(y_test, pred_svr))
print('Mean Squared Error:- ',mean_squared_error(y_test, pred_svr))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test, pred_svr)))
# Out:
# R2_score:  -0.02601699606409813
# R2_score on training data:-  18.19147829055051
# Mean Absolute Error:-  8.736980061020054
# Mean Squared Error:-  103.76705224391472
# Root Mean Squared Error:-  10.18661142107201

# %%
from sklearn.ensemble import ExtraTreesRegressor
ETR = ExtraTreesRegressor()
ETR.fit(x_train, y_train)
pred_ETR = ETR.predict(x_test)
pred_train = ETR.predict(x_train)
print('R2_score: ', r2_score(y_test, pred_ETR))
print('R2_score on training data:- ',r2_score(y_train, pred_train)*100)
print('Mean Absolute Error:- ',mean_absolute_error(y_test, pred_ETR))
print('Mean Squared Error:- ',mean_squared_error(y_test, pred_ETR))
print("Root Mean Squared Error:- ",np.sqrt(mean_squared_error(y_test, pred_ETR)))
# Out:
# R2_score:  0.6810978759765625
# R2_score on training data:-  100.0
# Mean Absolute Error:-  3.964444444444447
# Mean Squared Error:-  32.252422222222236
# Root Mean Squared Error:-  5.679121606571058

# %% [markdown]
# # Cross Validation Score

# %%
from sklearn.model_selection import cross_val_score

# %%
# Checking cv score for LinearRegression
score = cross_val_score(LR, x, y)
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is - ", r2_score(y_test, pred_LR) - score.mean())
# Out:
# [ 0.55279169 -3.45934599  0.2482195   0.32502308  0.8768194 ]
# -0.2912984644981275
# Difference between R2 score and cross validation score is -  1.2070302506338277

# %%
# Checking cv score for RandomForestRegression
score1 = cross_val_score(RFR, x, y)
print(score1)
print(score1.mean())
print("Difference between R2 score and cross validation score is - ", r2_score(y_test, pred_RFR) - score1.mean())
# Out:
# [ 0.14438268 -6.53473359  0.24610149  0.37218656  0.78411237]
# -0.9975900983408058
# Difference between R2 score and cross validation score is -  1.6639152082040871

# %%
# Checking cv score for KNeighborsRegressor
score2 = cross_val_score(KNN, x, y)
print(score2)
print(score2.mean())
print("Difference between R2 score and cross validation score is - ", r2_score(y_test, pred_KNN) - score2.mean())
# Out:
# [ 0.23758437 -4.06244275  0.18476771  0.22348509  0.48321893]
# -0.5866773299697532
# Difference between R2 score and cross validation score is -  1.2032544784072532

# %%
# Checking cv score for GradientBoostingRegressor
score3 = cross_val_score(GBR, x, y)
print(score3)
print(score3.mean())
print("Difference between R2 score and cross validation score is - ", r2_score(y_test, pred_GBR) - score3.mean())
# Out:
# [ 0.19461935 -7.61986745 -0.11791347  0.64822061  0.67928713]
# -1.243130763578147
# Difference between R2 score and cross validation score is -  1.496254322175338

# %%
# Checking cv score for Lasso
score4 = cross_val_score(LA, x, y)
print(score4)
print(score4.mean())
print("Difference between R2 score and cross validation score is - ", r2_score(y_test, pred_LA) - score4.mean())
# Out:
# [ 0.38324276 -1.41861952  0.54501742  0.39413068  0.90903189]
# 0.16256064593438455
# Difference between R2 score and cross validation score is -  0.7383910545493279

# %%
# Checking cv score for Ridge
score5 = cross_val_score(RD, x, y)
print(score5)
print(score5.mean())
print("Difference between R2 score and cross validation score is - ", r2_score(y_test, pred_RD) - score5.mean())
# Out:
# [ 0.55620659 -2.63617648  0.45732321  0.51997432  0.92151406]
# -0.03623165937958768
# Difference between R2 score and cross validation score is -  0.951963445515288

# %%
# Checking cv score for DecisionTreesRegressor
score6 = cross_val_score(DTR, x, y)
print(score6)
print(score6.mean())
print("Difference between R2 score and cross validation score is - ", r2_score(y_test, pred_DTR) - score6.mean())
# Out:
# [ -0.18294849 -11.6870229   -0.73191165   0.39529042   0.56863905]
# -2.327590713316341
# Difference between R2 score and cross validation score is -  1.6356961820663412

# %%
# Checking cv score for SVR
score7 = cross_val_score(svr, x, y)
print(score7)
print(score7.mean())
print("Difference between R2 score and cross validation score is - ", r2_score(y_test, pred_svr) - score7.mean())
# Out:
# [-0.14496661 -0.97764181 -0.30075651 -0.68110343 -0.0586563 ]
# -0.43262493058292684
# Difference between R2 score and cross validation score is -  0.4066079345188287

# %%
# Checking cv score for ETR
score8 = cross_val_score(ETR, x, y)
print(score8)
print(score8.mean())
print("Difference between R2 score and cross validation score is - ", r2_score(y_test, pred_ETR) - score8.mean())
# Out:
# [-0.01203242 -3.83870802  0.35940564  0.39294863  0.83503124]
# -0.45267098362460967
# Difference between R2 score and cross validation score is -  1.1337688596011721

# %% [markdown]
# # Ridge is our best Model

# %% [markdown]
# Ridge is our best Model because it has the highest R2 score among all the above tested models

# %% [markdown]
# # Hyper Parameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param = {'alpha':[1.0, .05, .4, 2],
         'fit_intercept': [True, False],
         'solver':['auto', 'svd', 'cholsky', 'lsqr', 'sag', 'saga', 'lbfgs'],
         'positive':[False, True],
         'random_state':[1, 4, 10, 20]}

# %%
gscv = GridSearchCV(Ridge(), param, cv = 5)

# %%
gscv.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=Ridge(),
#              param_grid={'alpha': [1.0, 0.05, 0.4, 2],
#                          'fit_intercept': [True, False],
#                          'positive': [False, True],
#                          'random_state': [1, 4, 10, 20],
#                          'solver': ['auto', 'svd', 'cholsky', 'lsqr', 'sag',
#                                     'saga', 'lbfgs']})

# %%
gscv.best_params_
# Out:
# {'alpha': 2,
#  'fit_intercept': True,
#  'positive': False,
#  'random_state': 20,
#  'solver': 'saga'}

# %%
Model = Ridge(alpha = 2, fit_intercept = True, positive = False, random_state = 20, solver = 'saga')

# %%
Model.fit(x_train, y_train)
print('R2 score: - ', r2_score(y_test, pred))
print('Mean Absolute Error: - ', mean_absolute_error(y_test, pred))
print('Mean Squared error: - ', mean_squared_error(y_test, pred))
print("Root Mean Squared Error: - ",np.sqrt(mean_squared_error(y_test, pred)))
# Out:
# R2 score: -  -1.188772131193415
# Mean Absolute Error: -  12.112034045256499
# Mean Squared error: -  221.36322591032663
# Root Mean Squared Error: -  14.878280341165999

# %% [markdown]
# # Saving the model

# %%
import joblib
joblib.dump(Model, "Baseball Case Study.pki")
# Out:
# ['Baseball Case Study.pki']

# %% [markdown]
# # Predicting the saved model

# %%
import pickle
filename = "Baseball Case Study.pki"
pickle.dump(Model, open(filename, 'wb'))

# %%
import pickle
loaded_model = pickle.load(open("Baseball Case Study.pki", 'rb'))
result = loaded_model.score(x_test, y_test)
print(result*100)
# Out:
# 86.30195248772762
